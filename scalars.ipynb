# %% [markdown]
# <a href="https://colab.research.google.com/github/Dulani-Viyathma/Maths/blob/main/scalars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A Scalar is a single numarical value

# %%
 a= 5
 b = 3
 print("Add: ",a+b)
 print("Substract: ",a-b)
 print("Multiply: ",a*b)
 print("devide:",a/b)

 Scalar = 3
 x = 5
 print(Scalar*x)
# Out:
# Add:  8
# Substract:  2
# Multiply:  15
# devide: 1.6666666666666667
# 15
